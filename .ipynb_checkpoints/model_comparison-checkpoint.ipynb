# %%
# %load_ext autoreload
# %autoreload 1

# %aimport plot_helpers
# %aimport file_helpers
# %aimport integration

# %%
from file_helpers import *
from plot_helpers import *
from integration import *
# %matplotlib inline

# %%
get_dir('data/manual')

# %%
validation = pd.read_csv
# Out:
# 15-07-17 DSC Prep #29-33 validation.xlsx        15-08-12 DSC Prep 29-52 validation.xlsx
# 15-07-22 DSC Prep #34-40 & POS validation.xlsx  ~$15-08-12 DSC Prep 29-52 validation.xlsx

# %%
all_preps = pd.read_excel('15-08-12 DSC Prep 29-52 validation.xlsx', skiprows = 2)
names = list(all_preps.columns)
names[8] = 'enthalpy'
all_preps.columns = names

# %%
all_preps[['Isolate ID', 'enthalpy']]
# Out:
#     Isolate ID                                           enthalpy
# 0           29                                              2.781
# 1           29                                              2.571
# 2           30                                              2.803
# 3           30                                              2.285
# 4           31                                               2.09
# 5           31                                                NaN
# 6           42  1.443 (cannot figure out how to change mg to c...
# 7           42                                              4.962
# 8           33                                              2.236
# 9           33                                              2.288
# 10          34                                              2.718
# 11          34                                              2.685
# 12          36                                              3.436
# ...

# %%
e = all_preps.enthalpy

# %%
map(float, e)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-f3b8fde72e50> in <module>()
# ----> 1 map(float, e)
#
# ValueError: invalid literal for float(): 1.443 (cannot figure out how to change mg to correct amount (also mislabeled as 31)
